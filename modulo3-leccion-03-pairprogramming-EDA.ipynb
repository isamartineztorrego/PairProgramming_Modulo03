# %% [markdown]
# ## Pair Programming EDA

# %% [markdown]
# Para realizar este pair programming deberéis usar el conjunto de datos de world-data-2023-part1.csv.
#
# En este fichero encontraremos la siguiente información:
#
# Country: Nombre del país.
#
# Density\n(P/Km2): Densidad de población medida en personas por kilómetro cuadrado.
#
# Abbreviation: Abreviatura o código que representa al país.
#
# Agricultural Land( %): Porcentaje del área total de tierra utilizada con fines agrícolas.
#
# Land Area(Km2): Área total de tierra del país en kilómetros cuadrados.
#
# Armed Forces size: Tamaño de las fuerzas armadas en el país.
#
# Birth Rate: Número de nacimientos por cada 1,000 habitantes por año.
#
# Calling Code: Código internacional de llamada para el país.
#
# Capital/Major City: Nombre de la capital o ciudad principal.
#
# Co2-Emissions: Emisiones de dióxido de carbono en toneladas.
#
# CPI: Índice de Precios al Consumidor (IPC), una medida de la inflación y el poder adquisitivo.
#
# CPI Change (%): Cambio porcentual en el Índice de Precios al Consumidor en comparación con el año anterior.
#
# Currency-Code: Código de moneda utilizado en el país.
#
# Fertility Rate: Número promedio de hijos nacidos de una mujer durante su vida.
#
# Forested Area (%): Porcentaje del área total cubierta por bosques.
#
# Gasoline Price: Precio de la gasolina por litro en moneda local.

# %% [markdown]
# ##### **Ejercicios de exploración del conjunto de datos**

# %%
import pandas as pd

# %% [markdown]
# 1. Muestra las primeras 5 filas del conjunto de datos.

# %%
#Abrimos el csv, con index_col=o porque hemos visto que tiene una primera columna Unnamed que es el índice que no queremos coger
df_world=pd.read_csv('world-data-2023_part1.csv', index_col=0)
df_world.head(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %% [markdown]
# 2. Muestra las últimas 5 filas del conjunto de datos.

# %%
df_world.tail(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %% [markdown]
# 3. Muestra una muestra aleatoria de 5 filas del conjunto de datos.

# %%
df_world.sample(5)
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 127  North Korea              214           KP                21.80%
# 64       Germany              240           DE                47.70%
# 136     Paraguay               18           PY                55.10%
# 106        Malta            1,380           MT                32.40%
# 82        Israel              400           IL                24.60%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 127        120,538         1,469,000       13.89         850.0
# 64         357,022           180,000        9.50          49.0
# 136        406,752            27,000       20.57         595.0
# 106            316             2,000        9.20         356.0
# 82          20,770           178,000       20.80         972.0
#
#     Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 127          Pyongyang        28,284     NaN            NaN           KPW
# 64              Berlin       727,973  112.85          1.40%           EUR
# 136           Asunci��         7,407  143.82          2.80%           PYG
# 106           Valletta         1,342  113.45          1.60%           EUR
# 82           Jerusalem        65,166  108.15          0.80%           ILS
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 127            1.90            40.70%         $0.58
# 64             1.56            32.70%         $1.39
# 136            2.43            37.70%         $1.04
# 106            1.23             1.10%         $1.36
# 82             3.09             7.70%         $1.57

# %% [markdown]
# 4. Muestra el nombre de todas las columnas en el conjunto de datos.

# %%
df_world.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# 5. Muestra los valores únicos en la columna "Abbreviation".

# %%
df_world['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %% [markdown]
# ##### **BONUS DE EXPLORACION**

# %% [markdown]
# 1. Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".

# %%
df_world['Abbreviation'].value_counts()
# Out:
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: Abbreviation, Length: 188, dtype: int64

# %% [markdown]
# 2. Verifica si hay valores nulos en el conjunto de datos.

# %%
df_world.isnull().sum()
# Out:
# Country                   0
# Density\n(P/Km2)          0
# Abbreviation              7
# Agricultural Land( %)     7
# Land Area(Km2)            1
# Armed Forces size        24
# Birth Rate                6
# Calling Code              1
# Capital/Major City        3
# Co2-Emissions             7
# CPI                      17
# CPI Change (%)           16
# Currency-Code            15
# Fertility Rate            7
# Forested Area (%)         7
# Gasoline Price           20
# dtype: int64

# %% [markdown]
# 3. Verifica si hay valores no nulos en el conjunto de datos.

# %%
df_world.notnull().sum()
# Out:
# Country                  195
# Density\n(P/Km2)         195
# Abbreviation             188
# Agricultural Land( %)    188
# Land Area(Km2)           194
# Armed Forces size        171
# Birth Rate               189
# Calling Code             194
# Capital/Major City       192
# Co2-Emissions            188
# CPI                      178
# CPI Change (%)           179
# Currency-Code            180
# Fertility Rate           188
# Forested Area (%)        188
# Gasoline Price           175
# dtype: int64

# %% [markdown]
# 4. Muestra información general sobre el conjunto de datos.

# %%
df_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    object
#  15  Gasoline Price         175 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 25.9+ KB

# %% [markdown]
# 5. Elimina una columna específica (por ejemplo, "Armed Forces size").

# %%
df_dropped=df_world.drop('Abbreviation', axis=1)
df_dropped.head(3)
# Out:
#        Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0  Afghanistan               60                58.10%        652,230
# 1      Albania              105                43.10%         28,748
# 2      Algeria               18                17.40%      2,381,741
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 0           323,000       32.49          93.0              Kabul
# 1             9,000       11.78         355.0             Tirana
# 2           317,000       24.28         213.0            Algiers
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 0         8,672   149.9          2.30%           AFN            4.47
# 1         4,536  119.05          1.40%           ALL            1.62
# 2       150,006  151.36          2.00%           DZD            3.02
#
#   Forested Area (%) Gasoline Price
# 0             2.10%         $0.70
# 1            28.10%         $1.36
# 2             0.80%         $0.28

# %%
#Otra forma sería
# df_dropped=df_worl(columns=['Armed Forces size'])

# %% [markdown]
# 6. Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
#1. creamos nuevo df con las columnas numéricas y lo visualizamos para comprobación
df_numerico=df_world.select_dtypes(include='number')
df_numerico.head(3)
# Out:
#    Birth Rate  Calling Code  Fertility Rate
# 0       32.49          93.0            4.47
# 1       11.78         355.0            1.62
# 2       24.28         213.0            3.02

# %%
#2. Usamos .describe() para ver las estadísticas
df_numerico.describe().T
# Out:
#                 count        mean         std   min     25%      50%  \
# Birth Rate      189.0   20.214974    9.945774  5.90  11.300   17.950
# Calling Code    194.0  360.546392  323.236419  1.00  82.500  255.500
# Fertility Rate  188.0    2.698138    1.282267  0.98   1.705    2.245
#
#                      75%      max
# Birth Rate       28.7500    46.08
# Calling Code    506.7500  1876.00
# Fertility Rate    3.5975     6.91

# %% [markdown]
# ##### **Ejercicios con loc e iloc**

# %% [markdown]
# 1. Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc.

# %%
df_world.loc[2:4, :]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 2  Algeria               18           DZ                17.40%      2,381,741
# 3  Andorra              164           AD                40.00%            468
# 4   Angola               26           AO                47.50%      1,246,700
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 2           317,000       24.28         213.0            Algiers
# 3               NaN        7.20         376.0   Andorra la Vella
# 4           117,000       40.73         244.0             Luanda
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 2       150,006  151.36          2.00%           DZD            3.02
# 3           469     NaN            NaN           EUR            1.27
# 4        34,693  261.73         17.10%           AOA            5.52
#
#   Forested Area (%) Gasoline Price
# 2             0.80%         $0.28
# 3            34.00%         $1.51
# 4            46.30%         $0.97

# %% [markdown]
# 2. Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.

# %%
df_birth_rate=df_world.loc[df_world['Birth Rate'] >30, :]
df_birth_rate
# Out:
#                               Country Density\n(P/Km2) Abbreviation  \
# 0                         Afghanistan               60           AF
# 4                              Angola               26           AO
# 18                              Benin              108           BJ
# 26                       Burkina Faso               76           BF
# 27                            Burundi              463           BI
# 28                        Ivory Coast               83           CI
# 31                           Cameroon               56           CM
# 33           Central African Republic                8           CF
# 34                               Chad               13           TD
# 38                            Comoros              467           KM
# 39              Republic of the Congo               16          NaN
# 45   Democratic Republic of the Congo               40           CD
# 53                  Equatorial Guinea               50           GQ
# 54                            Eritrea               35           ER
# 57                           Ethiopia              115           ET
# 61                              Gabon                9           GA
# 62                         The Gambia              239           GM
# 69                             Guinea               53           GN
# 70                      Guinea-Bissau               70           GW
# 96                            Liberia               53           LR
# 101                        Madagascar               48           MG
# 102                            Malawi              203           MW
# 105                              Mali               17           ML
# 108                        Mauritania                5           MR
# 117                        Mozambique               40           MZ
# 125                             Niger               19           NE
# 126                           Nigeria              226           NG
# 144                            Rwanda              525           RW
# 150                      S�����������              228           ST
# 152                           Senegal               87           SN
# 155                      Sierra Leone              111           SL
# 159                   Solomon Islands               25           SB
# 160                           Somalia               25           SO
# 163                       South Sudan               18           SS
# 166                             Sudan               25           SD
# 171                        Tajikistan               68           TJ
# 172                          Tanzania               67           TZ
# 175                              Togo              152           TG
# 182                            Uganda              229           UG
# 192                             Yemen               56           YE
# 193                            Zambia               25           ZM
# 194                          Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                  58.10%        652,230           323,000       32.49
# 4                  47.50%      1,246,700           117,000       40.73
# 18                 33.30%        112,622            12,000       36.22
# 26                 44.20%        274,200            11,000       37.93
# 27                 79.20%         27,830            31,000       39.01
# 28                 64.80%        322,463            27,000       35.74
# 31                 20.60%        475,440            24,000       35.39
# 33                  8.20%        622,984             8,000       35.35
# 34                 39.70%      1,284,000            35,000       42.17
# 38                 71.50%          2,235               NaN       31.88
# 39                 31.10%        342,000            12,000       32.86
# 45                 11.60%      2,344,858           134,000       41.18
# 53                 10.10%         28,051             1,000       33.24
# 54                 75.20%        117,600           202,000       30.30
# 57                 36.30%      1,104,300           138,000       32.34
# 61                 20.00%        267,667             7,000       31.61
# 62                 59.80%         11,300             1,000       38.54
# 69                 59.00%        245,857            13,000       36.36
# 70                 58.00%         36,125             4,000       35.13
# 96                 28.00%        111,369             2,000       33.04
# 101                71.20%        587,041            22,000       32.66
# 102                61.40%        118,484            15,000       34.12
# 105                33.80%      1,240,192            18,000       41.54
# 108                38.50%      1,030,700            21,000       33.69
# 117                63.50%        799,380            11,000       37.52
# 125                36.10%      1,267,000            10,000       46.08
# 126                77.70%        923,768           215,000       37.91
# 144                73.40%         26,338            35,000       31.70
# 150                50.70%            964             1,000       31.54
# 152                46.10%        196,722            19,000       34.52
# 155                54.70%         71,740             9,000       33.41
# 159                 3.90%         28,896               NaN       32.44
# 160                70.30%        637,657            20,000       41.75
# 163                   NaN        644,329           185,000       35.01
# 166                28.70%      1,861,484           124,000       32.18
# 171                34.10%        144,100            17,000       30.76
# 172                44.80%        947,300            28,000       36.70
# 175                70.20%         56,785            10,000       33.11
# 182                71.90%        241,038            46,000       38.14
# 192                44.60%        527,968            40,000       30.45
# 193                32.10%        752,618            16,000       36.19
# 194                41.90%        390,757            51,000       30.68
#
#      Calling Code Capital/Major City Co2-Emissions       CPI CPI Change (%)  \
# 0            93.0              Kabul         8,672     149.9          2.30%
# 4           244.0             Luanda        34,693    261.73         17.10%
# 18          229.0         Porto-Novo         6,476    110.71         -0.90%
# 26          226.0        Ouagadougou         3,418    106.58         -3.20%
# 27          257.0          Bujumbura           495    182.11         -0.70%
# 28          225.0       Yamoussoukro         9,674    111.61         -0.90%
# 31          237.0            Yaound�         8,291    118.65          2.50%
# 33          236.0             Bangui           297    186.86         37.10%
# 34          235.0          N'Djamena         1,016     117.7         -1.00%
# 38          269.0    Moroni, Comoros           202    103.62         -4.30%
# 39          242.0        Brazzaville         3,282    124.74          2.20%
# 45          243.0           Kinshasa         2,021    133.85          2.90%
# 53          240.0             Malabo         5,655    124.35          1.20%
# 54          291.0             Asmara           711       NaN            NaN
# 57          251.0        Addis Ababa        14,870    143.86         15.80%
# 61          241.0         Libreville         5,321    122.19          2.10%
# 62          220.0             Banjul           532    172.73          7.10%
# 69          224.0            Conakry         2,996    262.95          9.50%
# 70          245.0             Bissau           293    111.65          1.40%
# 96          231.0           Monrovia         1,386    223.13         23.60%
# 101         261.0       Antananarivo         3,905    184.33          5.60%
# 102         265.0           Lilongwe         1,298    418.34          9.40%
# 105         223.0             Bamako         3,179    108.73         -1.70%
# 108         222.0         Nouakchott         2,739    135.02          2.30%
# 117         258.0             Maputo         7,943    182.31          2.80%
# 125         227.0             Niamey         2,017    109.32         -2.50%
# 126         234.0              Abuja       120,369    267.51         11.40%
# 144         250.0             Kigali         1,115    151.09          3.40%
# 150         239.0              S����           121    185.09          7.90%
# 152         221.0              Dakar        10,902    109.25          1.80%
# 155         232.0           Freetown         1,093    234.16         14.80%
# 159         677.0            Honiara           169    133.06          1.60%
# 160         252.0          Mogadishu           645       NaN            NaN
# 163         211.0               Juba         1,727  4,583.71        187.90%
# 166         249.0           Khartoum        20,000  1,344.19         51.00%
# 171         992.0           Dushanbe         5,310    148.57          6.00%
# 172         255.0             Dodoma        11,973    187.43          3.50%
# 175         228.0               Lom�         3,000     113.3          0.70%
# 182         256.0            Kampala         5,680    173.87          2.90%
# 192         967.0              Sanaa        10,609    157.58          8.10%
# 193         260.0             Lusaka         5,141    212.31          9.20%
# 194         263.0             Harare        10,983    105.51          0.90%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 0             AFN            4.47             2.10%         $0.70
# 4             AOA            5.52            46.30%         $0.97
# 18            XOF            4.84            37.80%         $0.72
# 26            XOF            5.19            19.30%         $0.98
# 27            BIF            5.41            10.90%         $1.21
# 28            XOF            4.65            32.70%         $0.93
# 31            XAF            4.57            39.30%         $1.03
# 33            NaN            4.72            35.60%         $1.41
# 34            XAF            5.75             3.80%         $0.78
# 38            KMF            4.21            19.70%            NaN
# 39            XAF            4.43            65.40%         $0.97
# 45            CDF            5.92            67.20%         $1.49
# 53            XAF            4.51            55.50%            NaN
# 54            ERN            4.06            14.90%         $2.00
# 57            ETB            4.25            12.50%         $0.75
# 61            XAF            3.97            90.00%         $0.92
# 62            GMD            5.22            48.40%         $1.18
# 69            GNF            4.70            25.80%         $0.90
# 70            XOF            4.48            69.80%            NaN
# 96            NaN            4.32            43.10%         $0.80
# 101           MGA            4.08            21.40%         $1.11
# 102           MWK            4.21            33.20%         $1.15
# 105           XOF            5.88             3.80%         $1.12
# 108           MRU            4.56             0.20%         $1.13
# 117           MZN            4.85            48.00%         $0.65
# 125           XOF            6.91             0.90%         $0.88
# 126           NGN            5.39             7.20%         $0.46
# 144           RWF            4.04            19.70%         $1.17
# 150           STN            4.32            55.80%            NaN
# 152           XOF            4.63            42.80%         $1.14
# 155           SLL            4.26            43.10%         $1.08
# 159           SBD            4.40            77.90%            NaN
# 160           SOS            6.07            10.00%         $1.41
# 163           SSP            4.70               NaN         $0.28
# 166           SDG            4.41             8.10%         $0.95
# 171           TJS            3.59             3.00%         $0.71
# 172           TZS            4.89            51.60%         $0.87
# 175           XOF            4.32             3.10%         $0.71
# 182           UGX            4.96             9.70%         $0.94
# 192           YER            3.79             1.00%         $0.92
# 193           ZMW            4.63            65.20%         $1.40
# 194           NaN            3.62            35.50%         $1.34

# %% [markdown]
# 3. Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.

# %%
df_fertility=df_world.loc[df_world['Fertility Rate'] >3, ['Country', 'Capital/Major City']]
df_fertility
# Out:
#                               Country Capital/Major City
# 0                         Afghanistan              Kabul
# 2                             Algeria            Algiers
# 4                              Angola             Luanda
# 18                              Benin         Porto-Novo
# 26                       Burkina Faso        Ouagadougou
# 27                            Burundi          Bujumbura
# 28                        Ivory Coast       Yamoussoukro
# 31                           Cameroon            Yaound�
# 33           Central African Republic             Bangui
# 34                               Chad          N'Djamena
# 38                            Comoros    Moroni, Comoros
# 39              Republic of the Congo        Brazzaville
# 45   Democratic Republic of the Congo           Kinshasa
# 51                              Egypt              Cairo
# 53                  Equatorial Guinea             Malabo
# 54                            Eritrea             Asmara
# 57                           Ethiopia        Addis Ababa
# 61                              Gabon         Libreville
# 62                         The Gambia             Banjul
# 65                              Ghana              Accra
# 69                             Guinea            Conakry
# 70                      Guinea-Bissau             Bissau
# 80                               Iraq            Baghdad
# 82                             Israel          Jerusalem
# 88                              Kenya            Nairobi
# 89                           Kiribati       South Tarawa
# 91                         Kyrgyzstan            Bishkek
# 95                            Lesotho             Maseru
# 96                            Liberia           Monrovia
# 101                        Madagascar       Antananarivo
# 102                            Malawi           Lilongwe
# 105                              Mali             Bamako
# 107                  Marshall Islands             Majuro
# 108                        Mauritania         Nouakchott
# 111    Federated States of Micronesia            Palikir
# 117                        Mozambique             Maputo
# 119                           Namibia           Windhoek
# 125                             Niger             Niamey
# 126                           Nigeria              Abuja
# 131                          Pakistan          Islamabad
# 135                  Papua New Guinea       Port Moresby
# 144                            Rwanda             Kigali
# 148                             Samoa               Apia
# 150                      S�����������              S����
# 152                           Senegal              Dakar
# 155                      Sierra Leone           Freetown
# 159                   Solomon Islands            Honiara
# 160                           Somalia          Mogadishu
# 163                       South Sudan               Juba
# 166                             Sudan           Khartoum
# 171                        Tajikistan           Dushanbe
# 172                          Tanzania             Dodoma
# 174                        East Timor               Dili
# 175                              Togo               Lom�
# 176                             Tonga           Nuku����
# 182                            Uganda            Kampala
# 189                           Vanuatu          Port Vila
# 192                             Yemen              Sanaa
# 193                            Zambia             Lusaka
# 194                          Zimbabwe             Harare

# %% [markdown]
# 4. Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.

# %%
df_world.iloc[:, 0:4]
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
# [195 rows x 4 columns]

# %% [markdown]
# 5. Encuentra el valor en la fila 2 y columna 7 utilizando iloc.

# %%
df_world.iloc[2, 7]
# Out:
# 213.0

# %% [markdown]
# 6. Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc.

# %%
df_world.iloc[:, [0,2,5]]
# Out:
#          Country Abbreviation Armed Forces size
# 0    Afghanistan           AF           323,000
# 1        Albania           AL             9,000
# 2        Algeria           DZ           317,000
# 3        Andorra           AD               NaN
# 4         Angola           AO           117,000
# ..           ...          ...               ...
# 190    Venezuela           VE           343,000
# 191      Vietnam           VN           522,000
# 192        Yemen           YE            40,000
# 193       Zambia           ZM            16,000
# 194     Zimbabwe           ZW            51,000
#
# [195 rows x 3 columns]

# %% [markdown]
# ##### **BONUS DE LOC Y ILOC**

# %%
#Traemos el df para tenerlo a mano
df_world.head(1)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
#
#   Capital/Major City Co2-Emissions    CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672  149.9          2.30%           AFN
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70

# %% [markdown]
# 1. Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.

# %%
#1. Creamos filtro
filtro=df_world['Abbreviation'] == 'AL'

#2. Aplicamos el filtro y seleccionamos la columna que queremos ver ('Gasoline Price')
valor_gasolina=df_world.loc[filtro, 'Gasoline Price']
valor_gasolina
# Out:
# 1    $1.36
# Name: Gasoline Price, dtype: object

# %%
#3. Comprobamos el resultado sacando la fila sobre la que hemos hecho el filtro
fila=df_world[df_world['Abbreviation'] == 'AL']
fila
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 1  Albania              105           AL                43.10%         28,748
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 1             9,000       11.78         355.0             Tirana
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 1         4,536  119.05          1.40%           ALL            1.62
#
#   Forested Area (%) Gasoline Price
# 1            28.10%         $1.36

# %%
#Otra forma sería
#valor_gasolina=df_world.loc[df_world['Abbreviation'] == 'AL', 'Gasoline Price'].values[0]
# Out:
# '$1.36 '

# %% [markdown]
# 2. Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.

# %%
#Creamos el filtro directamente en el .loc
pais=df_world.loc[df_world['Capital/Major City'] == 'Tirana']
pais
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 1  Albania              105           AL                43.10%         28,748
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 1             9,000       11.78         355.0             Tirana
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 1         4,536  119.05          1.40%           ALL            1.62
#
#   Forested Area (%) Gasoline Price
# 1            28.10%         $1.36

# %% [markdown]
# 3. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.

# %%
cpi=df_world.loc[df_world["CPI"] == "128.85", :]
cpi
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 40  Costa Rica              100           CR                34.50%
#
#    Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 40         51,100            10,000       13.97         506.0
#
#    Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 40      San Jos������         8,023  128.85          2.10%           CRC
#
#     Fertility Rate Forested Area (%) Gasoline Price
# 40            1.75            54.60%         $0.98

# %% [markdown]
# 4. Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.

# %%
densidad=df_world.loc[df_world['Abbreviation']=='AD', 'Density\n(P/Km2)'].values[0]
densidad
# Out:
# '164'

# %% [markdown]
# 5. Selecciona las columnas "Country" y "Co2-Emissions".

# %%
columnas=df_world[["Country", "Co2-Emissions"]]
columnas
# Out:
#          Country Co2-Emissions
# 0    Afghanistan         8,672
# 1        Albania         4,536
# 2        Algeria       150,006
# 3        Andorra           469
# 4         Angola        34,693
# ..           ...           ...
# 190    Venezuela       164,175
# 191      Vietnam       192,668
# 192        Yemen        10,609
# 193       Zambia         5,141
# 194     Zimbabwe        10,983
#
# [195 rows x 2 columns]

# %% [markdown]
# 6. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI cambió un 2% (columna "CPI Change (%)").

# %%
changed_cpi=df_world.loc[df_world['CPI Change (%)'] == "2", :]
changed_cpi
# Out:
# Empty DataFrame
# Columns: [Country, Density
# (P/Km2), Abbreviation, Agricultural Land( %), Land Area(Km2), Armed Forces size, Birth Rate, Calling Code, Capital/Major City, Co2-Emissions, CPI, CPI Change (%), Currency-Code, Fertility Rate, Forested Area (%), Gasoline Price]
# Index: []

# %% [markdown]
# 7. Encuentra la tasa de natalidad (columna "Birth Rate") para el país con la abreviatura "AF" utilizando loc.

# %%
natalidad=df_world.loc[df_world['Abbreviation']=='AF', 'Birth Rate'].values[0]
natalidad
# Out:
# 32.49

# %% [markdown]
# 8. Selecciona todas las columnas de las filas 3 a 5 (excluyendo la fila 5) utilizando iloc.

# %%
seleccion=df_world.iloc[3:5, :]
seleccion
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 3  Andorra              164           AD                40.00%            468
# 4   Angola               26           AO                47.50%      1,246,700
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 3               NaN        7.20         376.0   Andorra la Vella
# 4           117,000       40.73         244.0             Luanda
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 3           469     NaN            NaN           EUR            1.27
# 4        34,693  261.73         17.10%           AOA            5.52
#
#   Forested Area (%) Gasoline Price
# 3            34.00%         $1.51
# 4            46.30%         $0.97

# %% [markdown]
# 9. Selecciona las columnas 1, 3 y 6 para todas las filas utilizando iloc.

# %%
seleccion1=df_world.iloc[:, [1, 3, 6]]
seleccion1
# Out:
#     Density\n(P/Km2) Agricultural Land( %)  Birth Rate
# 0                 60                58.10%       32.49
# 1                105                43.10%       11.78
# 2                 18                17.40%       24.28
# 3                164                40.00%        7.20
# 4                 26                47.50%       40.73
# ..               ...                   ...         ...
# 190               32                24.50%       17.88
# 191              314                39.30%       16.75
# 192               56                44.60%       30.45
# 193               25                32.10%       36.19
# 194               38                41.90%       30.68
#
# [195 rows x 3 columns]
